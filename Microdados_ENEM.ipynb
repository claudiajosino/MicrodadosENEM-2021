# %% [markdown]
# <a href="https://colab.research.google.com/github/claudiajosino/MicrodadosEnem-2021/blob/main/Microdados_ENEM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd   
import matplotlib.pyplot as plt
import numpy as np

# %%
microdadosEnem = pd.read_csv('MICRODADOS_ENEM_2021.csv', sep=";", encoding='ISO-8859-1')

# %%
microdadosEnem.head()
# Out:
#   NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  \
# 0  2,10054E+11    2021                5       F                1            1
# 1  2,10052E+11    2021               12       M                1            1
# 2  2,10053E+11    2021               13       F                3            1
# 3  2,10052E+11    2021                3       M                1            3
# 4  2,10051E+11    2021                2       F                1            3
#
#    TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  ...  Q016  \
# 0                 1                1                3          1  ...     A
# 1                 1                1               11          1  ...     A
# 2                 1                1               15          1  ...     B
# 3                 1                2                0          2  ...     A
# 4                 1                2                0          2  ...     B
#
# ...

# %%
colunasSelecionadasEnem=['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
       'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
       'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
       'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
       'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
       'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
       'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
       'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
       'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
       'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
       'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
       'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
       'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
       'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
       'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
       'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
       'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
       'Q023', 'Q024', 'Q025']

# %%
microdadosEnemSelecionado = microdadosEnem.filter(items=colunasSelecionadasEnem)

# %%
# Colunas selecionadas

# %%
microdadosEnemSelecionado.head()
# Out:
#   NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  \
# 0  2,10054E+11    2021                5       F                1            1
# 1  2,10052E+11    2021               12       M                1            1
# 2  2,10053E+11    2021               13       F                3            1
# 3  2,10052E+11    2021                3       M                1            3
# 4  2,10051E+11    2021                2       F                1            3
#
#    TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  ...  Q016  \
# 0                 1                1                3          1  ...     A
# 1                 1                1               11          1  ...     A
# 2                 1                1               15          1  ...     B
# 3                 1                2                0          2  ...     A
# 4                 1                2                0          2  ...     B
#
# ...

# %%
# Estado dos participantes

# %%
coluna_no_estado = microdadosEnemSelecionado['SG_UF_ESC']

# %%
# Quantidade de participantes de cada estado

# %%
coluna_no_estado.value_counts().sort_index
# Out:
# <bound method Series.sort_index of CE    56604
# SP    43323
# GO    27295
# RJ    20958
# MG    19806
# BA    16554
# PE    15250
# PR    13109
# RS    10535
# PA     9910
# SC     7952
# MA     7359
# PB     7346
# ES     6936
# DF     5451
# PI     5154
# AM     5033
# RN     5021
# MT     4646
# AL     4109
# MS     3410
# SE     3350
# RO     2582
# TO     1970
# AC     1124
# AP      903
# RR      558
# Name: SG_UF_ESC, dtype: int64>

# %%
#Idade dos participantes

# %%
coluna_no_idade = microdadosEnemSelecionado['TP_FAIXA_ETARIA']

# %%
# Faixa Etária (Resumo)

# %%
coluna_no_idade.value_counts().sort_index()
# Out:
# 1      65507
# 2     223995
# 3     261872
# 4     132243
# 5      76634
# 6      47863
# 7      32708
# 8      23077
# 9      18974
# 10     14664
# 11     43571
# 12     22876
# 13     16527
# 14     10131
# 15      5967
# 16      3251
# 17      1642
# 18       616
# 19       207
# 20        83
# Name: TP_FAIXA_ETARIA, dtype: int64

# %%
# 2 a 5  = 17 a 20 anos -> Faixa etária mais frequente

# %%
coluna_no_idade.hist(bins=20)
# Out:
# <Axes: >

# %%
# Declaração da cor da pele

# %%
coluna_no_raca = microdadosEnemSelecionado['TP_COR_RACA']

# %%
coluna_no_raca.value_counts().sort_index()
# Out:
# 0     21541
# 1    382502
# 2    122452
# 3    449723
# 4     21021
# 5      5168
# 6         1
# Name: TP_COR_RACA, dtype: int64

# %%
# 1 -> Branca / 3 - Parda

# %%
coluna_no_raca.hist(bins=20)
# Out:
# <Axes: >

# %%
# Nota do enem de acordo com o Sexo do participante

# %%
colunasSelecionadas = ['TP_SEXO' , 'NU_NOTA_REDACAO']

# %%
microdadosEnemSexoRedacao = microdadosEnem.filter(items=colunasSelecionadas)

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').describe()
# Out:
#         NU_NOTA_REDACAO                                                    \
#                   count        mean         std  min    25%    50%    75%
# TP_SEXO
# F              532553.0  638.440118  187.420391  0.0  540.0  620.0  780.0
# M              250841.0  612.539019  197.173083  0.0  520.0  600.0  740.0
#
#
#             max
# TP_SEXO
# F        1000.0
# M        1000.0

# %%
# Dados do questionário Socioeconômico (Influência dos Pais na nota do ENEM)

# %%
colunasSelecionadas = ['NU_INSCRICAO',
                       'NU_NOTA_REDACAO', 
                       'Q001', 'Q002']

# %%
# Criação um novo DataFrame apenas com os dados que serão analisados:

# %%
microdadosEnemSelecionado = microdadosEnem.filter(items=colunasSelecionadas)

# %%
#Visualizar a cabeça (head) do DataFrame retirando os valores "NaN":

# %%
microdadosEnemSelecionado = microdadosEnemSelecionado.dropna()

# %%
microdadosEnemSelecionado.head()
# Out:
#   NU_INSCRICAO  NU_NOTA_REDACAO Q001 Q002
# 0  2,10054E+11            760.0    F    F
# 1  2,10052E+11            560.0    B    B
# 3  2,10052E+11            780.0    B    B
# 4  2,10051E+11            780.0    D    E
# 6  2,10053E+11            480.0    B    C

# %%
# Começando pelas duas primeiras questões:

#Q001 - Até que série seu pai, ou o homem responsável por você, estudou?

#Q002 - Até que série sua mãe, ou a mulher responsável por você, estudou?

# %%
# PASSO 1 : Definindo um dicionário:

# %%
q001e002Dicionario = {
'A': 'Nunca estudou',
'B':'Não completou a 4ª série/5º ano do Ensino Fundamental',
'C':'Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental',
'D':'Completou a 8ª série/9º ano do Ensino Fundamental, mas não completou o Ensino Médio',
'E':'Completou o Ensino Médio, mas não completou a Faculdade',
'F':'Completou a Faculdade, mas não completou a Pós-graduação',
'G':'Completou a Pós-graduação',
'H':'Não sei'}

# %%
microdadosEnemSelecionado.filter(items=['Q001','NU_INSCRICAO']).groupby('Q001').count()
# Out:
#       NU_INSCRICAO
# Q001
# A            28509
# B           131436
# C           106615
# D            92836
# E           236943
# F            69475
# G            48942
# H            68637

# %%
microdadosEnemSelecionado['NO_Q001'] = [q001e002Dicionario[resp] for resp in microdadosEnemSelecionado.Q001]

# %%
microdadosEnemSelecionado.head()
# Out:
#   NU_INSCRICAO  NU_NOTA_REDACAO Q001 Q002  \
# 0  2,10054E+11            760.0    F    F
# 1  2,10052E+11            560.0    B    B
# 3  2,10052E+11            780.0    B    B
# 4  2,10051E+11            780.0    D    E
# 6  2,10053E+11            480.0    B    C
#
#                                              NO_Q001
# 0  Completou a Faculdade, mas não completou a Pós...
# 1  Não completou a 4ª série/5º ano do Ensino Fund...
# 3  Não completou a 4ª série/5º ano do Ensino Fund...
# 4  Completou a 8ª série/9º ano do Ensino Fundamen...
# 6  Não completou a 4ª série/5º ano do Ensino Fund...

# %%
# PASSO 2 : Criando novas colunas no DataFrame

# %%
# Coluna NO_Q001:

# %%
microdadosEnemSelecionado['NO_Q001'] = [q001e002Dicionario[resp] for resp in microdadosEnemSelecionado.Q001]

# %%
microdadosEnemSelecionado.head()
# Out:
#   NU_INSCRICAO  NU_NOTA_REDACAO Q001 Q002  \
# 0  2,10054E+11            760.0    F    F
# 1  2,10052E+11            560.0    B    B
# 3  2,10052E+11            780.0    B    B
# 4  2,10051E+11            780.0    D    E
# 6  2,10053E+11            480.0    B    C
#
#                                              NO_Q001
# 0  Completou a Faculdade, mas não completou a Pós...
# 1  Não completou a 4ª série/5º ano do Ensino Fund...
# 3  Não completou a 4ª série/5º ano do Ensino Fund...
# 4  Completou a 8ª série/9º ano do Ensino Fundamen...
# 6  Não completou a 4ª série/5º ano do Ensino Fund...

# %%
# Inserido coluna NO_Q002:

# %%
microdadosEnemSelecionado['NO_Q002'] = [q001e002Dicionario[resp] for resp in microdadosEnemSelecionado.Q002]

# %%
microdadosEnemSelecionado.head()
# Out:
#   NU_INSCRICAO  NU_NOTA_REDACAO Q001 Q002  \
# 0  2,10054E+11            760.0    F    F
# 1  2,10052E+11            560.0    B    B
# 3  2,10052E+11            780.0    B    B
# 4  2,10051E+11            780.0    D    E
# 6  2,10053E+11            480.0    B    C
#
#                                              NO_Q001  \
# 0  Completou a Faculdade, mas não completou a Pós...
# 1  Não completou a 4ª série/5º ano do Ensino Fund...
# 3  Não completou a 4ª série/5º ano do Ensino Fund...
# 4  Completou a 8ª série/9º ano do Ensino Fundamen...
# 6  Não completou a 4ª série/5º ano do Ensino Fund...
#
#                                              NO_Q002
# 0  Completou a Faculdade, mas não completou a Pós...
# 1  Não completou a 4ª série/5º ano do Ensino Fund...
# 3  Não completou a 4ª série/5º ano do Ensino Fund...
# 4  Completou o Ensino Médio, mas não completou a ...
# 6  Completou a 4ª série/5º ano, mas não completou...

# %%
# Passo 3: Comparando distribução do nível de escolaridade Pai x Mãe no conjunto de dados, 
# Utilizando os métodos do DataFrame filter(), groupby(), count(), sort_values()

# %%
# 1 - Distribuição dos candidatos do ENEM 2021 por escolaridade do Pai

# %%
microdadosEnemSelecionado.filter(items=['NU_INSCRICAO','NO_Q001']).\
groupby('NO_Q001').count().sort_values(by='NU_INSCRICAO', ascending=False)
# Out:
#                                                     NU_INSCRICAO
# NO_Q001
# Completou o Ensino Médio, mas não completou a F...        236943
# Não completou a 4ª série/5º ano do Ensino Funda...        131436
# Completou a 4ª série/5º ano, mas não completou ...        106615
# Completou a 8ª série/9º ano do Ensino Fundament...         92836
# Completou a Faculdade, mas não completou a Pós-...         69475
# Não sei                                                    68637
# Completou a Pós-graduação                                  48942
# Nunca estudou                                              28509

# %%
# 2 - Distribuição dos candidatos do ENEM 2021 por escolaridade da Mãe

# %%
microdadosEnemSelecionado.filter(items=['NU_INSCRICAO','NO_Q002']).\
groupby('NO_Q002').count().sort_values(by='NU_INSCRICAO', ascending=False)
# Out:
#                                                     NU_INSCRICAO
# NO_Q002
# Completou o Ensino Médio, mas não completou a F...        289140
# Completou a 8ª série/9º ano do Ensino Fundament...         97285
# Completou a Faculdade, mas não completou a Pós-...         95377
# Não completou a 4ª série/5º ano do Ensino Funda...         90853
# Completou a 4ª série/5º ano, mas não completou ...         87966
# Completou a Pós-graduação                                  86356
# Não sei                                                    19562
# Nunca estudou                                              16854

# %%
# Passo 4: Olhando o desempenho em redação segundo a escolaridade Pai x Mãe

# %%
# 1 - Por Escolaridade do Pai

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q001']).\
groupby('NO_Q001').mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q001
# Completou a Pós-graduação                                737.724654
# Completou a Faculdade, mas não completou a Pós-...       717.420079
# Completou o Ensino Médio, mas não completou a F...       649.178072
# Completou a 8ª série/9º ano do Ensino Fundament...       618.314878
# Completou a 4ª série/5º ano, mas não completou ...       605.914552
# Não completou a 4ª série/5º ano do Ensino Funda...       582.124380
# Não sei                                                  579.873246
# Nunca estudou                                            546.198744

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.suptitle('Pai (Nota Redação x Escolaridade) ')

microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','Q001']).\
groupby('Q001').mean().sort_values(by='NU_NOTA_REDACAO', ascending=False).plot(ax=ax)
# Out:
# <Axes: xlabel='Q001'>

# %%
#2 - por Escolaridade da Mãe

# %%
q002Redacao = microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q002']).\
groupby('NO_Q002').mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)

# %%
q002Redacao
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação                                723.010804
# Completou a Faculdade, mas não completou a Pós-...       704.950931
# Completou o Ensino Médio, mas não completou a F...       643.240043
# Completou a 8ª série/9º ano do Ensino Fundament...       610.092895
# Completou a 4ª série/5º ano, mas não completou ...       596.879227
# Não completou a 4ª série/5º ano do Ensino Funda...       575.987981
# Não sei                                                  544.990127
# Nunca estudou                                            534.778275

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.suptitle('Mãe (Nota Redação x Escolaridade) ')

q002Redacao = microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','Q002']).\
groupby('Q002').mean().sort_values(by='NU_NOTA_REDACAO', ascending=False).plot(ax=ax)

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q001']).groupby('NO_Q001').describe()
# Out:
#                                                    NU_NOTA_REDACAO  \
#                                                              count
# NO_Q001
# Completou a 4ª série/5º ano, mas não completou ...        106615.0
# Completou a 8ª série/9º ano do Ensino Fundament...         92836.0
# Completou a Faculdade, mas não completou a Pós-...         69475.0
# Completou a Pós-graduação                                  48942.0
# Completou o Ensino Médio, mas não completou a F...        236943.0
# Nunca estudou                                              28509.0
# Não completou a 4ª série/5º ano do Ensino Funda...        131436.0
# Não sei                                                    68637.0
#
#                                                                             \
#                                                           mean         std
# NO_Q001
# Completou a 4ª série/5º ano, mas não completou ...  605.914552  188.613862
# ...

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q002']).groupby('NO_Q002').describe()
# Out:
#                                                    NU_NOTA_REDACAO  \
#                                                              count
# NO_Q002
# Completou a 4ª série/5º ano, mas não completou ...         87966.0
# Completou a 8ª série/9º ano do Ensino Fundament...         97285.0
# Completou a Faculdade, mas não completou a Pós-...         95377.0
# Completou a Pós-graduação                                  86356.0
# Completou o Ensino Médio, mas não completou a F...        289140.0
# Nunca estudou                                              16854.0
# Não completou a 4ª série/5º ano do Ensino Funda...         90853.0
# Não sei                                                    19562.0
#
#                                                                             \
#                                                           mean         std
# NO_Q002
# Completou a 4ª série/5º ano, mas não completou ...  587.942614  190.176201
# ...

# %%
 # Dados do questionário Socioeconômico (Estado)

# %%
#Selecionar colunas de interesse:

# %%
colunasSelecionadas = ['NU_INSCRICAO', 'SG_UF_PROVA',
                       'NU_NOTA_REDACAO','Q001'
                       'Q002']

# %%
microdadosEnemSelecionado['SG_UF_PROVA'] = microdadosEnem.SG_UF_PROVA.dropna()

# %%
ax = microdadosEnemSelecionado.filter(items=['SG_UF_PROVA','Q002','NU_NOTA_REDACAO'])\
                        .groupby(['Q002', 'SG_UF_PROVA'])\
                        .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)\
                        .unstack().plot(figsize=(16,8), colormap='viridis')
ax.set_title('Nota Redação x Escolaridade x Estado', fontsize=20)

handles, labels = ax.get_legend_handles_labels()

import re
edited_labels = [re.search(',\s(.+?)\)',label).group(1) for label in labels]
ax.legend(edited_labels, bbox_to_anchor=(1.05, 1), loc=2 , borderaxespad=0.)

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q002'])\
                   .where(microdadosEnemSelecionado.SG_UF_PROVA == 'RO')\
                   .groupby('NO_Q002')\
                   .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação                                667.454350
# Completou a Faculdade, mas não completou a Pós-...       656.175772
# Completou o Ensino Médio, mas não completou a F...       604.425770
# Completou a 8ª série/9º ano do Ensino Fundament...       584.924925
# Completou a 4ª série/5º ano, mas não completou ...       565.840979
# Não sei                                                  547.549669
# Não completou a 4ª série/5º ano do Ensino Funda...       542.179310
# Nunca estudou                                            493.815789

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q002'])\
                   .where(microdadosEnemSelecionado.SG_UF_PROVA == 'AC')\
                   .groupby('NO_Q002')\
                   .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação                                671.022364
# Completou a Faculdade, mas não completou a Pós-...       653.343653
# Completou o Ensino Médio, mas não completou a F...       607.354430
# Completou a 8ª série/9º ano do Ensino Fundament...       579.662921
# Completou a 4ª série/5º ano, mas não completou ...       566.729412
# Não completou a 4ª série/5º ano do Ensino Funda...       544.288107
# Não sei                                                  543.971631
# Nunca estudou                                            503.796296

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q002'])\
                   .where(microdadosEnemSelecionado.SG_UF_PROVA == 'AP')\
                   .groupby('NO_Q002')\
                   .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação                                685.781250
# Completou a Faculdade, mas não completou a Pós-...       651.980831
# Completou o Ensino Médio, mas não completou a F...       590.379910
# Completou a 8ª série/9º ano do Ensino Fundament...       569.113924
# Completou a 4ª série/5º ano, mas não completou ...       560.891720
# Não completou a 4ª série/5º ano do Ensino Funda...       551.735537
# Nunca estudou                                            526.057143
# Não sei                                                  492.222222

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q002'])\
                   .where(microdadosEnemSelecionado.SG_UF_PROVA == 'TO')\
                   .groupby('NO_Q002')\
                   .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação                                685.633508
# Completou a Faculdade, mas não completou a Pós-...       669.686099
# Completou o Ensino Médio, mas não completou a F...       605.972222
# Completou a 4ª série/5º ano, mas não completou ...       568.724584
# Completou a 8ª série/9º ano do Ensino Fundament...       564.677419
# Não sei                                                  541.863354
# Não completou a 4ª série/5º ano do Ensino Funda...       539.005146
# Nunca estudou                                            477.522124
