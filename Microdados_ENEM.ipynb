# %% [markdown]
# <a href="https://colab.research.google.com/github/claudiajosino/MicrodadosEnem-2021/blob/main/Microdados_ENEM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd   
import matplotlib.pyplot as plt
import numpy as np

# %%
microdadosEnem = pd.read_csv('MICRODADOS_ENEM_2021.csv', sep=";", encoding='ISO-8859-1')

# %%
microdadosEnem.head()
# Out:
#   NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  \
# 0  2,10054E+11    2021                5       F                1            1
# 1  2,10052E+11    2021               12       M                1            1
# 2  2,10053E+11    2021               13       F                3            1
# 3  2,10052E+11    2021                3       M                1            3
# 4  2,10051E+11    2021                2       F                1            3
#
#    TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  ...  Q016  \
# 0                 1                1                3          1  ...     A
# 1                 1                1               11          1  ...     A
# 2                 1                1               15          1  ...     B
# 3                 1                2                0          2  ...     A
# 4                 1                2                0          2  ...     B
#
#    Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# 0     A     A    B     A    A     B     A     B     B
# 1     A     A    B     A    A     C     A     A     A
# 2     A     A    B     A    A     C     B     B     B
# 3     A     A    B     A    A     B     A     B     B
# 4     A     A    B     A    B     E     A     B     B
#
# [5 rows x 76 columns]

# %%
colunasSelecionadasEnem=['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
       'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
       'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
       'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
       'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
       'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
       'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
       'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
       'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
       'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
       'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
       'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
       'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
       'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
       'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
       'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
       'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
       'Q023', 'Q024', 'Q025']

# %%
microdadosEnemSelecionado = microdadosEnem.filter(items=colunasSelecionadasEnem)

# %%
# Colunas selecionadas

# %%
microdadosEnemSelecionado.head()
# Out:
#   NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  TP_COR_RACA  \
# 0  2,10054E+11    2021                5       F                1            1
# 1  2,10052E+11    2021               12       M                1            1
# 2  2,10053E+11    2021               13       F                3            1
# 3  2,10052E+11    2021                3       M                1            3
# 4  2,10051E+11    2021                2       F                1            3
#
#    TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  ...  Q016  \
# 0                 1                1                3          1  ...     A
# 1                 1                1               11          1  ...     A
# 2                 1                1               15          1  ...     B
# 3                 1                2                0          2  ...     A
# 4                 1                2                0          2  ...     B
#
#    Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# 0     A     A    B     A    A     B     A     B     B
# 1     A     A    B     A    A     C     A     A     A
# 2     A     A    B     A    A     C     B     B     B
# 3     A     A    B     A    A     B     A     B     B
# 4     A     A    B     A    B     E     A     B     B
#
# [5 rows x 76 columns]

# %%
# Estado dos participantes

# %%
coluna_no_estado = microdadosEnemSelecionado['SG_UF_ESC']

# %%
# Quantidade de participantes de cada estado

# %%
coluna_no_estado.value_counts().sort_index
# Out:
# <bound method Series.sort_index of CE    56604
# SP    43323
# GO    27295
# RJ    20958
# MG    19806
# BA    16554
# PE    15250
# PR    13109
# RS    10535
# PA     9910
# SC     7952
# MA     7359
# PB     7346
# ES     6936
# DF     5451
# PI     5154
# AM     5033
# RN     5021
# MT     4646
# AL     4109
# MS     3410
# SE     3350
# RO     2582
# TO     1970
# AC     1124
# AP      903
# RR      558
# Name: SG_UF_ESC, dtype: int64>

# %%
coluna_no_estado.hist(bins=20)
# Out:
# <Axes: >

# %%
#Idade dos participantes

# %%
coluna_no_idade = microdadosEnemSelecionado['TP_FAIXA_ETARIA']

# %%
# Faixa Etária (Resumo)

# %%
coluna_no_idade.value_counts().sort_index()
# Out:
# 1      69161
# 2     233804
# 3     272709
# 4     138026
# 5      80154
# 6      50259
# 7      34397
# 8      24292
# 9      19994
# 10     15429
# 11     45811
# 12     24053
# 13     17360
# 14     10682
# 15      6323
# 16      3437
# 17      1724
# 18       649
# 19       217
# 20        94
# Name: TP_FAIXA_ETARIA, dtype: int64

# %%
# 2 a 5  = 17 a 20 anos -> Faixa etária mais frequente

# %%
coluna_no_idade.hist(bins=20)
# Out:
# <Axes: >

# %%
# Declaração da cor da pele

# %%
coluna_no_raca = microdadosEnemSelecionado['TP_COR_RACA']

# %%
coluna_no_raca.value_counts().sort_index()
# Out:
# 0     22521
# 1    401457
# 2    127898
# 3    469360
# 4     21938
# 5      5400
# 6         1
# Name: TP_COR_RACA, dtype: int64

# %%
# 1 -> Branca / 3 - Parda

# %%
coluna_no_raca.hist(bins=20)
# Out:
# <Axes: >

# %%
# Nota do enem de acordo com o Sexo do participante

# %%
colunasSelecionadas = ['TP_SEXO' , 'NU_NOTA_REDACAO']

# %%
microdadosEnemSexoRedacao = microdadosEnem.filter(items=colunasSelecionadas)

# %%
microdadosEnemSexoRedacao.groupby('TP_SEXO').describe()
# Out:
#         NU_NOTA_REDACAO                                                    \
#                   count        mean         std  min    25%    50%    75%
# TP_SEXO
# F              556000.0  638.373489  187.392800  0.0  540.0  620.0  780.0
# M              263301.0  612.262468  197.120871  0.0  520.0  600.0  740.0
#
#
#             max
# TP_SEXO
# F        1000.0
# M        1000.0

# %%
# Dados do questionário Socioeconômico (Influência dos Pais na nota do ENEM)

# %%
colunasSelecionadas = ['NU_INSCRICAO',
                       'NU_NOTA_MT','NU_NOTA_REDACAO', 
                       'Q001', 'Q002']

# %%
# Criação um novo DataFrame apenas com os dados que serão analisados:

# %%
microdadosEnemSelecionado = microdadosEnem.filter(items=colunasSelecionadas)

# %%
#Visualizar a cabeça (head) do DataFrame retirando os valores "NaN":

# %%
microdadosEnemSelecionado = microdadosEnemSelecionado.dropna()

# %%
microdadosEnemSelecionado.head()
# Out:
#   NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002
# 1  2,10052E+11       461.5            560.0    B    B
# 3  2,10052E+11       659.5            780.0    B    B
# 4  2,10051E+11       582.6            780.0    D    E
# 8  2,10053E+11       493.4            520.0    B    B
# 9  2,10051E+11       413.3            380.0    D    D

# %%
# Começando pelas duas primeiras questões:

#Q001 - Até que série seu pai, ou o homem responsável por você, estudou?

#Q002 - Até que série sua mãe, ou a mulher responsável por você, estudou?

# %%
# PASSO 1 : Definindo um dicionário:

# %%
q001e002Dicionario = {
'A': 'Nunca estudou',
'B':'Não completou a 4ª série/5º ano do Ensino Fundamental',
'C':'Completou a 4ª série/5º ano, mas não completou a 8ª série/9º ano do Ensino Fundamental',
'D':'Completou a 8ª série/9º ano do Ensino Fundamental, mas não completou o Ensino Médio',
'E':'Completou o Ensino Médio, mas não completou a Faculdade',
'F':'Completou a Faculdade, mas não completou a Pós-graduação',
'G':'Completou a Pós-graduação',
'H':'Não sei'}

# %%
microdadosEnemSelecionado.filter(items=['Q001','NU_INSCRICAO']).groupby('Q001').count()
# Out:
#       NU_INSCRICAO
# Q001
# A            27911
# B           129112
# C           105312
# D            91725
# E           237025
# F            70872
# G            50235
# H            66775

# %%
microdadosEnemSelecionado['NO_Q001'] = [q001e002Dicionario[resp] for resp in microdadosEnemSelecionado.Q001]

# %%
microdadosEnemSelecionado.head()
# Out:
#   NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 1  2,10052E+11       461.5            560.0    B    B
# 3  2,10052E+11       659.5            780.0    B    B
# 4  2,10051E+11       582.6            780.0    D    E
# 8  2,10053E+11       493.4            520.0    B    B
# 9  2,10051E+11       413.3            380.0    D    D
#
#                                              NO_Q001
# 1  Não completou a 4ª série/5º ano do Ensino Fund...
# 3  Não completou a 4ª série/5º ano do Ensino Fund...
# 4  Completou a 8ª série/9º ano do Ensino Fundamen...
# 8  Não completou a 4ª série/5º ano do Ensino Fund...
# 9  Completou a 8ª série/9º ano do Ensino Fundamen...

# %%
# PASSO 2 : Criando novas colunas no DataFrame

# %%
# Coluna NO_Q001:

# %%
microdadosEnemSelecionado['NO_Q001'] = [q001e002Dicionario[resp] for resp in microdadosEnemSelecionado.Q001]

# %%
microdadosEnemSelecionado.head()
# Out:
#   NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 1  2,10052E+11       461.5            560.0    B    B
# 3  2,10052E+11       659.5            780.0    B    B
# 4  2,10051E+11       582.6            780.0    D    E
# 8  2,10053E+11       493.4            520.0    B    B
# 9  2,10051E+11       413.3            380.0    D    D
#
#                                              NO_Q001
# 1  Não completou a 4ª série/5º ano do Ensino Fund...
# 3  Não completou a 4ª série/5º ano do Ensino Fund...
# 4  Completou a 8ª série/9º ano do Ensino Fundamen...
# 8  Não completou a 4ª série/5º ano do Ensino Fund...
# 9  Completou a 8ª série/9º ano do Ensino Fundamen...

# %%
# Inserido coluna NO_Q002:

# %%
microdadosEnemSelecionado['NO_Q002'] = [q001e002Dicionario[resp] for resp in microdadosEnemSelecionado.Q002]

# %%
microdadosEnemSelecionado.head()
# Out:
#   NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 1  2,10052E+11       461.5            560.0    B    B
# 3  2,10052E+11       659.5            780.0    B    B
# 4  2,10051E+11       582.6            780.0    D    E
# 8  2,10053E+11       493.4            520.0    B    B
# 9  2,10051E+11       413.3            380.0    D    D
#
#                                              NO_Q001  \
# 1  Não completou a 4ª série/5º ano do Ensino Fund...
# 3  Não completou a 4ª série/5º ano do Ensino Fund...
# 4  Completou a 8ª série/9º ano do Ensino Fundamen...
# 8  Não completou a 4ª série/5º ano do Ensino Fund...
# 9  Completou a 8ª série/9º ano do Ensino Fundamen...
#
#                                              NO_Q002
# 1  Não completou a 4ª série/5º ano do Ensino Fund...
# 3  Não completou a 4ª série/5º ano do Ensino Fund...
# 4  Completou o Ensino Médio, mas não completou a ...
# 8  Não completou a 4ª série/5º ano do Ensino Fund...
# 9  Completou a 8ª série/9º ano do Ensino Fundamen...

# %%
# Passo 3: Comparando distribução do nível de escolaridade Pai x Mãe no conjunto de dados, 
# Utilizando os métodos do DataFrame filter(), groupby(), count(), sort_values()

# %%
# 1 - Distribuição dos candidatos do ENEM 2021 por escolaridade do Pai

# %%
microdadosEnemSelecionado.filter(items=['NU_INSCRICAO','NO_Q001']).\
groupby('NO_Q001').count().sort_values(by='NU_INSCRICAO', ascending=False)
# Out:
#                                                     NU_INSCRICAO
# NO_Q001
# Completou o Ensino Médio, mas não completou a F...        237025
# Não completou a 4ª série/5º ano do Ensino Funda...        129112
# Completou a 4ª série/5º ano, mas não completou ...        105312
# Completou a 8ª série/9º ano do Ensino Fundament...         91725
# Completou a Faculdade, mas não completou a Pós-...         70872
# Não sei                                                    66775
# Completou a Pós-graduação                                  50235
# Nunca estudou                                              27911

# %%
# 2 - Distribuição dos candidatos do ENEM 2021 por escolaridade da Mãe

# %%
microdadosEnemSelecionado.filter(items=['NU_INSCRICAO','NO_Q002']).\
groupby('NO_Q002').count().sort_values(by='NU_INSCRICAO', ascending=False)
# Out:
#                                                     NU_INSCRICAO
# NO_Q002
# Completou o Ensino Médio, mas não completou a F...        287978
# Completou a Faculdade, mas não completou a Pós-...         96848
# Completou a 8ª série/9º ano do Ensino Fundament...         95513
# Não completou a 4ª série/5º ano do Ensino Funda...         88837
# Completou a Pós-graduação                                  88270
# Completou a 4ª série/5º ano, mas não completou ...         86224
# Não sei                                                    18896
# Nunca estudou                                              16401

# %%
# Passo 4: Olhando o desempenho em redação segundo a escolaridade Pai x Mãe

# %%
# 1 - Por Escolaridade do Pai

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q001']).\
groupby('NO_Q001').mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q001
# Completou a Pós-graduação                                742.847417
# Completou a Faculdade, mas não completou a Pós-...       722.385145
# Completou o Ensino Médio, mas não completou a F...       656.020420
# Completou a 8ª série/9º ano do Ensino Fundament...       626.848078
# Completou a 4ª série/5º ano, mas não completou ...       613.981692
# Não completou a 4ª série/5º ano do Ensino Funda...       589.623273
# Não sei                                                  589.065668
# Nunca estudou                                            553.755150

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.suptitle('Pai (Nota Redação x Escolaridade) ')

microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','Q001']).\
groupby('Q001').mean().sort_values(by='NU_NOTA_REDACAO', ascending=False).plot(ax=ax)
# Out:
# <Axes: xlabel='Q001'>

# %%
#2 - por Escolaridade da Mãe

# %%
q002Redacao = microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q002']).\
groupby('NO_Q002').mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)

# %%
q002Redacao
# Out:
#                                                     NU_NOTA_REDACAO
# NO_Q002
# Completou a Pós-graduação                                722.949360
# Completou a Faculdade, mas não completou a Pós-...       704.848835
# Completou o Ensino Médio, mas não completou a F...       642.907722
# Completou a 8ª série/9º ano do Ensino Fundament...       609.856041
# Completou a 4ª série/5º ano, mas não completou ...       596.577055
# Não completou a 4ª série/5º ano do Ensino Funda...       575.447167
# Não sei                                                  544.799958
# Nunca estudou                                            533.949149

# %%
fig, ax = plt.subplots(figsize=(6,4))
plt.suptitle('Mãe (Nota Redação x Escolaridade) ')

q002Redacao = microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','Q002']).\
groupby('Q002').mean().sort_values(by='NU_NOTA_REDACAO', ascending=False).plot(ax=ax)

# %%
microdadosEnemSelecionado.filter(items=['NU_NOTA_REDACAO','NO_Q001']).groupby('NO_Q001').describe()
# Out:
#                                                    NU_NOTA_REDACAO  \
#                                                              count
# NO_Q001
# Completou a 4ª série/5º ano, mas não completou ...        105312.0
# Completou a 8ª série/9º ano do Ensino Fundament...         91725.0
# Completou a Faculdade, mas não completou a Pós-...         70872.0
# Completou a Pós-graduação                                  50235.0
# Completou o Ensino Médio, mas não completou a F...        237025.0
# Nunca estudou                                              27911.0
# Não completou a 4ª série/5º ano do Ensino Funda...        129112.0
# Não sei                                                    66775.0
#
#                                                                             \
#                                                           mean         std
# NO_Q001
# Completou a 4ª série/5º ano, mas não completou ...  613.981692  182.413647
# Completou a 8ª série/9º ano do Ensino Fundament...  626.848078  181.174475
# Completou a Faculdade, mas não completou a Pós-...  722.385145  165.323423
# Completou a Pós-graduação                           742.847417  162.756880
# Completou o Ensino Médio, mas não completou a F...  656.020420  176.160392
# Nunca estudou                                       553.755150  192.143272
# Não completou a 4ª série/5º ano do Ensino Funda...  589.623273  182.845067
# Não sei                                             589.065668  186.931275
#
#                                                                               \
#                                                     min    25%    50%    75%
# NO_Q001
# Completou a 4ª série/5º ano, mas não completou ...  0.0  520.0  600.0  740.0
# Completou a 8ª série/9º ano do Ensino Fundament...  0.0  540.0  620.0  760.0
# Completou a Faculdade, mas não completou a Pós-...  0.0  600.0  740.0  860.0
# Completou a Pós-graduação                           0.0  640.0  760.0  880.0
# Completou o Ensino Médio, mas não completou a F...  0.0  560.0  640.0  800.0
# Nunca estudou                                       0.0  460.0  560.0  660.0
# Não completou a 4ª série/5º ano do Ensino Funda...  0.0  500.0  580.0  700.0
# Não sei                                             0.0  500.0  580.0  700.0
#
#
#                                                        max
# NO_Q001
# Completou a 4ª série/5º ano, mas não completou ...  1000.0
# Completou a 8ª série/9º ano do Ensino Fundament...  1000.0
# Completou a Faculdade, mas não completou a Pós-...  1000.0
# Completou a Pós-graduação                           1000.0
# Completou o Ensino Médio, mas não completou a F...  1000.0
# Nunca estudou                                        980.0
# Não completou a 4ª série/5º ano do Ensino Funda...   980.0
# Não sei                                              980.0

# %%
 # Dados do questionário Socioeconômico (Estado)

# %%
#Selecionar colunas de interesse:

# %%
colunasSelecionadas = ['NU_INSCRICAO', 'SG_UF_PROVA',
                       'NU_NOTA_MT','NU_NOTA_REDACAO', 
                       'Q001', 'Q002']

# %%
microdadosEnemSelecionado['SG_UF_PROVA'] = microdadosEnem.SG_UF_PROVA.dropna()

# %%
microdadosEnemSelecionado.head()
# Out:
#   NU_INSCRICAO  NU_NOTA_MT  NU_NOTA_REDACAO Q001 Q002  \
# 1  2,10052E+11       461.5            560.0    B    B
# 3  2,10052E+11       659.5            780.0    B    B
# 4  2,10051E+11       582.6            780.0    D    E
# 8  2,10053E+11       493.4            520.0    B    B
# 9  2,10051E+11       413.3            380.0    D    D
#
#                                              NO_Q001  \
# 1  Não completou a 4ª série/5º ano do Ensino Fund...
# 3  Não completou a 4ª série/5º ano do Ensino Fund...
# 4  Completou a 8ª série/9º ano do Ensino Fundamen...
# 8  Não completou a 4ª série/5º ano do Ensino Fund...
# 9  Completou a 8ª série/9º ano do Ensino Fundamen...
#
#                                              NO_Q002 SG_UF_PROVA
# 1  Não completou a 4ª série/5º ano do Ensino Fund...          AL
# 3  Não completou a 4ª série/5º ano do Ensino Fund...          CE
# 4  Completou o Ensino Médio, mas não completou a ...          CE
# 8  Não completou a 4ª série/5º ano do Ensino Fund...          MG
# 9  Completou a 8ª série/9º ano do Ensino Fundamen...          BA

# %%
ax = microdadosEnemSelecionado.filter(items=['SG_UF_PROVA','Q002','NU_NOTA_REDACAO'])\
                        .groupby(['Q002', 'SG_UF_PROVA'])\
                        .mean().sort_values(by='NU_NOTA_REDACAO', ascending=False)\
                        .unstack().plot(figsize=(16,8), colormap='viridis')
ax.set_title('Nota Redação x Escolaridade x Estado', fontsize=20)

handles, labels = ax.get_legend_handles_labels()

import re
edited_labels = [re.search(',\s(.+?)\)',label).group(1) for label in labels]
ax.legend(edited_labels, bbox_to_anchor=(1.05, 1), loc=2 , borderaxespad=0.)
